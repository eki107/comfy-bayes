# %%
from comfy_bayes.bayes_conversion import ConversionTest
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# matplotlib styling
plt.rcParams['figure.figsize'] = (20, 10)
sns.set_style("whitegrid")

# %%
from comfy_bayes.conversion_plotting import *

# %%
# observed data
success_A = 200
total_A = 1000
success_B = 230
total_B = 1000

ab_test = ConversionTest(success_A, total_A, success_B, total_B)

# %%
pd.DataFrame(index=[0], data=ab_test.get_stats())
# Out:
#    conversion_a  conversion_b  b_better_than_a    uplift      loss  \
# 0           0.2          0.23         0.948618  0.030336  0.000396
#
#    hdi_95_lower_a  hdi_95_lower_b  hdi_95_upper_a  hdi_95_upper_b
# 0        0.176392        0.204992        0.225937        0.257104

# %%
draw_probability_distributions(ab_test)

# %%
draw_approximate_distribution_of_difference(ab_test, samples=1_000_000)
